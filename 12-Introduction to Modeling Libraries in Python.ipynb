# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # 魔法命令

# %% [markdown]
# ### 基本命令

# %% [markdown]
# #### %timeit 监测命令执行时间

# %%
a = np.random.standard_normal((100, 100))
# %timeit np.dot(a, a)
# Out:
# 63.6 µs ± 3.19 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# #### 查看命令用法

# %%
# %debug?
# Out:
# Docstring:
# ::
#
#   %debug [--breakpoint FILE:LINE] [statement ...]
#
# Activate the interactive debugger.
#
# This magic command support two ways of activating debugger.
# One is to activate debugger before executing code.  This way, you
# can set a break point, to step through the code from the point.
# You can use this mode by giving statements to execute and optionally
# a breakpoint.
#
# The other one is to activate debugger in post-mortem mode.  You can
# activate this mode simply running %debug without any argument.
# If an exception has just occurred, this lets you inspect its stack
# frames interactively.  Note that this will always work only on the last
# traceback that occurred, so you must call this quickly after an
# exception that you wish to inspect has fired, because if another one
# occurs, it clobbers the previous one.
#
# If you want IPython to automatically do this on every exception, see
# the %pdb magic for more details.
#
# .. versionchanged:: 7.3
# ...

# %% [markdown]
# #### 查看当前路径，赋予一个变量

# %%
path = %pwd
path
# Out:
# 'C:\\Users\\lpc80\\PycharmProjects\\learn-pydata'

# %% [markdown]
# #### 查看所有的魔法命令

# %%
 # %quickref
# Out:
# IPython -- An enhanced Interactive Python - Quick Reference Card
# ...
#
# obj?, obj??      : Get help, or more help for object (also works as
#                    ?obj, ??obj).
# ?foo.*abc*       : List names in 'foo' containing 'abc' in them.
# %magic           : Information about IPython's 'magic' % functions.
#
# Magic functions are prefixed by % or %%, and typically take their arguments
# without parentheses, quotes or even commas for convenience.  Line magics take a
# single % and cell magics are prefixed with two %%.
#
# Example magic function calls:
#
# %alias d ls -F   : 'd' is now an alias for 'ls -F'
# alias d ls -F    : Works if 'alias' not a python name
# alist = %alias   : Get list of aliases to 'alist'
# cd /usr/share    : Obvious. cd -<tab> to choose from visited dirs.
# %cd??            : See help AND source for magic %cd
# %timeit x=10     : time the 'x=10' statement with high precision.
# %%timeit x=2**100
# ...

# %%
# %magic
# Out:
# IPython's 'magic' functions
# ...
#
# The magic function system provides a series of functions which allow you to
# control the behavior of IPython itself, plus a lot of system-type
# features. There are two kinds of magics, line-oriented and cell-oriented.
#
# Line magics are prefixed with the % character and work much like OS
# command-line calls: they get as an argument the rest of the line, where
# arguments are passed without parentheses or quotes.  For example, this will
# time the given statement::
#
#         %timeit range(1000)
#
# Cell magics are prefixed with a double %%, and they are functions that get as
# an argument not only the rest of the line, but also the lines below it in a
# separate argument.  These magics are called with two arguments: the rest of the
# call line and the body of the cell, consisting of the lines below the first.
# For example::
#
#         %%timeit x = numpy.random.randn((100, 100))
#         numpy.linalg.svd(x)
#
# ...

# %% [markdown]
# ### %run

# %%
# %run script.py

# %%
# 可以访问脚本文件中的变量
c
# Out:
# 7.5

# %%
result
# Out:
# 1.4666666666666666

# %% [markdown]
# #### %load 加载脚本文件

# %%
# %load script.py
def f(x, y, z):
    return (x + y) / z

a = 5
b = 6
c = 7.5

result = f(a, b, c)

# %% [markdown]
# ### 从剪切板执行代码

# %% [markdown]
# %paste
# %cpaste
# 可以在ipython shell中粘贴代码，但在jupyter中无效

# %% [markdown]
# # 使用命令行历史

# %% [markdown]
# ### 查询重用
#
# %run 后面输入之前用过指令的部分名字，可以用来查询该指令，ctrl+p（或者方向↑） 向前滚动，ctrl+n（或者方向↓） 向后滚动
#
# ctrl+r 快捷键然后输入名字也可以用来查询

# %% [markdown]
# ### 输入输出变量名

# %%
a=1
a
# Out:
# 1

# %%
b=2
b
# Out:
# 2

# %% [markdown]
# #### _和__分别用来记录前两次输出的结果

# %%
_
# Out:
# 2

# %%
__
# Out:
# 2

# %% [markdown]
# #### _i25和_25分别用来记录输入框的内容和变量值

# %%
_i25
# Out:
# 'a=1\na'

# %%
_25
# Out:
# 1

# %% [markdown]
# ### 几个魔法值来释放内存

# %%
# %hist # 打印所有输入历史
# Out:
# print('hello')
# print('hello')
# print('hello')
# print('hello')
# print('hello')
# a = np.random.standard_normal((100, 100))
# %timeit np.dot(a, a)
# import numpy as np
# import pandas as pd
# a = np.random.standard_normal((100, 100))
# %timeit np.dot(a, a)
# %%debug?
# %debug?
# path = %pwd
# path
#  %quickref
# %magic
# %run script.py
# c
# result
# # 可以访问脚本文件中的变量
# c
# %load script.py
# # %load script.py
# def f(x, y, z):
#     return (x + y) / z
#
# a = 5
# b = 6
# c = 7.5
#
# result = f(a, b, c)
# # %load script.py
# def f(x, y, z):
#     return (x + y) / z
#
# a = 5
# b = 6
# c = 7.5
#
# result = f(a, b, c)
# # %load script.py
# def f(x, y, z):
#     return (x + y) / z
#
# a = 5
# b = 6
# c = 7.5
#
# result = f(a, b, c)
# # %load script.py
# def f(x, y, z):
#     return (x + y) / z
#
# a = 5
# b = 6
# c = 7.5
#
# result = f(a, b, c)
#  a_command = foo(x, y, z)
# def foo(x,y,x):
#     print(x)
#
# a_command = foo(x, y, z)
# def foo(x,y,x):
#     print(x)
#
# ...

# %%
# %reset #清除名称空间，输入输出缓存（可选）
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])?  n
# Nothing done.

# %%
# 清除一个具体的对象 在del命令不一定有用的情况下 此命令可以用来释放内存
# %xdel b
# Out:
# NameError: name 'b' is not defined

# %% [markdown]
# # 与操作系统交互

# %% [markdown]
# ### shell命令和别名

# %%
ip_info = !ipconfig
ip_info
# Out:
# ['',
#  'Windows IP 配置',
#  '',
#  '',
#  '无线局域网适配器 WLAN:',
#  '',
#  '   媒体状态  . . . . . . . . . . . . : 媒体已断开连接',
#  '   连接特定的 DNS 后缀 . . . . . . . : DHCP HOST',
#  '',
#  '无线局域网适配器 本地连接* 1:',
#  '',
#  '   媒体状态  . . . . . . . . . . . . : 媒体已断开连接',
#  '   连接特定的 DNS 后缀 . . . . . . . : ',
#  '',
#  '无线局域网适配器 本地连接* 2:',
#  '',
#  '   媒体状态  . . . . . . . . . . . . : 媒体已断开连接',
#  '   连接特定的 DNS 后缀 . . . . . . . : ',
#  '',
#  '以太网适配器 以太网:',
#  '',
#  '   连接特定的 DNS 后缀 . . . . . . . : DHCP HOST',
#  '   本地链接 IPv6 地址. . . . . . . . : fe80::8edb:adef:8212:11f6%7',
#  '   IPv4 地址 . . . . . . . . . . . . : 192.168.0.111',
#  '   子网掩码  . . . . . . . . . . . . : 255.255.255.0',
#  '   默认网关. . . . . . . . . . . . . : 192.168.0.1']

# %%
foo = '*.png'
# !dir $foo
# Out:
#  驱动器 C 中的卷是 系统
#  卷的序列号是 B8C1-8110
#
#  C:\Users\lpc80\PycharmProjects\learn-pydata 的目录
#
# 2023/04/03  00:05            67,880 img.png
# 2023/04/03  00:05            67,880 img_1.png
#                2 个文件        135,760 字节
#                0 个目录 132,817,518,592 可用字节

# %%
# 给指令取别名
# %alias ll ls -l
# ll /usr
# 给多个指令取别名
# %alias test_alias (cd examples; ls; cd ..)
# test_alias

# %% [markdown]
# ### 目录书签系统

# %%
# %bookmark py4da D:\testmark
# %cd py4da
# !dir
# Out:
# (bookmark:py4da) -> D:\testmark
# D:\testmark
#  驱动器 D 中的卷是 文件
#  卷的序列号是 94BF-367B
#
#  D:\testmark 的目录
#
# 2023/04/16  10:56    <DIR>          .
# 2023/04/16  10:56    <DIR>          ..
# 2023/04/16  10:56                 0 a.txt
#                1 个文件              0 字节
#                2 个目录 25,521,221,632 可用字节

# %%
# %bookmark -l
# Out:
# Current bookmarks:
# py4da -> D:\testmark

# %% [markdown]
# # 软件开发工具

# %% [markdown]
# ### 交互式Debugger

# %%
# %bookmark workdir C:\Users\lpc80\PycharmProjects\learn-pydata
# %cd workdir
# Out:
# (bookmark:workdir) -> C:\Users\lpc80\PycharmProjects\learn-pydata
# C:\Users\lpc80\PycharmProjects\learn-pydata

# %%
run ./examples/ipython_bug.py
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# File ~\PycharmProjects\learn-pydata\examples\ipython_bug.py:15
#      12     works_fine()
#      13     throws_an_exception()
# ---> 15 calling_things()
#
# File ~\PycharmProjects\learn-pydata\examples\ipython_bug.py:13, in calling_things()
#      11 def calling_things():
#      12     works_fine()
# ---> 13     throws_an_exception()
#
# File ~\PycharmProjects\learn-pydata\examples\ipython_bug.py:9, in throws_an_exception()
#       7 a = 5
#       8 b = 6
# ----> 9 assert(a + b == 10)
#
# AssertionError:

# %% [markdown]
# #### 使用u和d可以在栈帧间切换

# %%
# %debug
# Out:
# > c:\users\lpc80\pycharmprojects\learn-pydata\examples\ipython_bug.py(9)throws_an_exception()
#       7     a = 5
#       8     b = 6
# ----> 9     assert(a + b == 10)
#      10
#      11 def calling_things():
# ipdb>  u
# > c:\users\lpc80\pycharmprojects\learn-pydata\examples\ipython_bug.py(13)calling_things()
#      11 def calling_things():
#      12     works_fine()
# ---> 13     throws_an_exception()
#      14
#      15 calling_things()
# ipdb>  u
# > c:\users\lpc80\pycharmprojects\learn-pydata\examples\ipython_bug.py(15)<module>()
#      11 def calling_things():
#      12     works_fine()
#      13     throws_an_exception()
#      14
# ---> 15 calling_things()
# ipdb>  u
# > c:\users\lpc80\miniconda3\envs\pydata-book\lib\site-packages\ipython\utils\py3compat.py(55)execfile()
#      53     with open(fname, "rb") as f:
#      54         compiler = compiler or compile
# ---> 55         exec(compiler(f.read(), fname, "exec"), glob, loc)
#      56
#      57
# ipdb>  u
# ...

# %% [markdown]
# #### 使用-d进入debug模式

# %% [markdown]
# s (step) 进入脚本
#
# b 12 在12行设置断点
#
# c 继续直到断点处停下
#
# n(next) 前进一行
#
# !a 查看变量a的值

# %% [markdown]
# | Command                  | Action                                                       |
# | ------------------------ | ------------------------------------------------------------ |
# | h(elp)                   | Display command list                                         |
# | help command             | Show documentation for command                               |
# | c(ontinue)               | Resume program execution                                     |
# | q(uit)                   | Exit debugger without executing any more code                |
# | b(reak)                  | number Set breakpoint at number in current file              |
# | b path/to/file.py:number | Set breakpoint at line number in specified file              |
# | s(tep)                   | Step into function call                                      |
# | n(ext)                   | Execute current line and advance to next line at current level |
# | u(p)/d(own)              | Move up/down in function call stack                          |
# | a(rgs)                   | Show arguments for current function                          |
# | debug                    | statement Invoke statement statement in new (recursive) debugger |
# | l(ist)                   | statement Show current position and context at current level of stack |
# | w(here)                  | Print full stack trace with context at current position      |

# %%
run -d examples/ipython_bug.py
# Out:
# Breakpoint 1 at c:\users\lpc80\pycharmprojects\learn-pydata\examples\ipython_bug.py:1
# NOTE: Enter 'c' at the ipdb>  prompt to continue execution.
# > c:\users\lpc80\pycharmprojects\learn-pydata\examples\ipython_bug.py(1)<module>()
# 1---> 1 def works_fine():
#       2     a = 5
#       3     b = 6
#       4     assert(a + b == 11)
#       5
# ipdb>  b 12
# Breakpoint 2 at c:\users\lpc80\pycharmprojects\learn-pydata\examples\ipython_bug.py:12
# ipdb>  c
# > c:\users\lpc80\pycharmprojects\learn-pydata\examples\ipython_bug.py(12)calling_things()
#      10
#      11 def calling_things():
# 2--> 12     works_fine()
#      13     throws_an_exception()
#      14
# ipdb>  n
# > c:\users\lpc80\pycharmprojects\learn-pydata\examples\ipython_bug.py(13)calling_things()
#      11 def calling_things():
# 2    12     works_fine()
# ---> 13     throws_an_exception()
#      14
#      15 calling_things()
# ipdb>  s
# --Call--
# ...

# %% [markdown]
# #### 其他使用debugger的方式

# %%
from IPython.core.debugger import Pdb

def set_trace():
     Pdb.set_trace(sys._getframe().f_back)
def debug(f, *args, **kwargs):
     pdb = Pdb()
     return pdb.runcall(f, *args, **kwargs)

# %%
run examples/ipython_bug.py
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File ~\PycharmProjects\learn-pydata\examples\ipython_bug.py:16
#      13     set_trace() # 这一行用来以其他方式调用debugger
#      14     throws_an_exception()
# ---> 16 calling_things()
#
# File ~\PycharmProjects\learn-pydata\examples\ipython_bug.py:13, in calling_things()
#      11 def calling_things():
#      12     works_fine()
# ---> 13     set_trace() # 这一行用来以其他方式调用debugger
#      14     throws_an_exception()
#
# NameError: name 'set_trace' is not defined

# %%
def f(x, y, z=1):
     tmp = x + y
     return tmp / z
debug(f, 1, 2, z=3)
# Out:
# > c:\users\lpc80\appdata\local\temp\ipykernel_16452\2769285481.py(2)f()
# ipdb>  s
# > c:\users\lpc80\appdata\local\temp\ipykernel_16452\2769285481.py(3)f()
# ipdb>  n
# --Return--
# 1.0
# > c:\users\lpc80\appdata\local\temp\ipykernel_16452\2769285481.py(3)f()
# ipdb>  q

# %%
# %run -d -b2 examples/ipython_bug.py
# Out:
# Breakpoint 1 at c:\users\lpc80\pycharmprojects\learn-pydata\examples\ipython_bug.py:2
# NOTE: Enter 'c' at the ipdb>  prompt to continue execution.
# > c:\users\lpc80\pycharmprojects\learn-pydata\examples\ipython_bug.py(1)<module>()
# ----> 1 def works_fine():
# 1     2     a = 5
#       3     b = 6
#       4     assert(a + b == 11)
#       5
# ipdb>  q

# %% [markdown]
# ### %time 和 %timeit

# %% [markdown]
# #### python原生time模块记录执行时间

# %%
import time
start = time.time()
iterations =10_0000
sum = 0
for i in range(iterations):
     # some code to run here
    sum+=i  
elapsed_per = (time.time() - start) / iterations
elapsed_per
# Out:
# 2.3984432220458987e-07

# %% [markdown]
# #### 使用%time

# %%
strings = ['foo', 'foobar', 'baz', 'qux',
         'python', 'Guido Van Rossum'] * 100000
method1 = [x for x in strings if x.startswith('foo')]
method2 = [x for x in strings if x[:3] == 'foo']

# %%
# %time method1 = [x for x in strings if x.startswith('foo')]
# Out:
# CPU times: total: 109 ms
# Wall time: 111 ms

# %%
# %time method2 = [x for x in strings if x[:3] == 'foo']
# Out:
# CPU times: total: 93.8 ms
# Wall time: 101 ms

# %% [markdown]
# #### 使用%timeit

# %%
# %timeit [x for x in strings if x.startswith('foo')]
# Out:
# 91.4 ms ± 3.35 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %timeit [x for x in strings if x[:3] == 'foo']
# Out:
# 83.7 ms ± 1.04 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
x = 'foobar'
y = 'foo'
# %timeit x.startswith(y)
# Out:
# 180 ns ± 2.17 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
# %timeit x[:3] == y
# Out:
# 182 ns ± 2.15 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### 基本profile %prun and %run -p

# %% [markdown]
# #### 在终端中使用该包
# ```bash
# python -m cProfile cprof_example.py
# ```

# %% [markdown]
# #### 编程式使用该工具

# %%
import numpy as np
from numpy.linalg import eigvals

def run_experiment(niter=100):
    K = 100
    results = []
    for _ in range(niter):
        mat = np.random.standard_normal((K, K))
        max_eigenvalue = np.abs(eigvals(mat)).max()
        results.append(max_eigenvalue)
    return results
some_results = run_experiment()
print('Largest one we saw: {0}'.format(np.max(some_results)))

# %prun -l 7 -s cumulative run_experiment()
# Out:
# Largest one we saw: 11.456129080258144
#          4004 function calls (3904 primitive calls) in 0.260 seconds
#
#    Ordered by: cumulative time
#    List reduced from 35 to 7 due to restriction <7>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.260    0.260 {built-in method builtins.exec}
#         1    0.000    0.000    0.260    0.260 <string>:1(<module>)
#         1    0.001    0.001    0.260    0.260 4097915401.py:4(run_experiment)
#       100    0.000    0.000    0.230    0.002 <__array_function__ internals>:177(eigvals)
#   200/100    0.000    0.000    0.229    0.002 {built-in method numpy.core._multiarray_umath.implement_array_function}
#       100    0.225    0.002    0.229    0.002 linalg.py:983(eigvals)
#       100    0.029    0.000    0.029    0.000 {method 'standard_normal' of 'numpy.random.mtrand.RandomState' objects}

# %%
# %run -p -s cumulative cprof_example.py
# Out:
# Largest one we saw: 11.320581290596484
#          4183 function calls (4082 primitive calls) in 0.296 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#       2/1    0.000    0.000    0.296    0.296 {built-in method builtins.exec}
#         1    0.000    0.000    0.296    0.296 <string>:1(<module>)
#         1    0.000    0.000    0.296    0.296 interactiveshell.py:2819(safe_execfile)
#         1    0.000    0.000    0.294    0.294 py3compat.py:51(execfile)
#         1    0.000    0.000    0.293    0.293 cprof_example.py:1(<module>)
#         1    0.001    0.001    0.293    0.293 cprof_example.py:4(run_experiment)
#       100    0.000    0.000    0.258    0.003 <__array_function__ internals>:177(eigvals)
#   201/101    0.000    0.000    0.258    0.003 {built-in method numpy.core._multiarray_umath.implement_array_function}
#       100    0.250    0.002    0.257    0.003 linalg.py:983(eigvals)
# ...

# %%
# can use the %%prun magic (two % signs) to profile an entire code block.

# %% [markdown]
# ### Profiling a Function Line by Line

# %%
# 前提是安装指定包 pip install line_profiler
# %load_ext line_profiler
# Out:
# The line_profiler extension is already loaded. To reload it, use:
#   %reload_ext line_profiler

# %%
# %run prof_mod
x = randn(3000, 3000)
y = randn(3000, 3000)
# %prun add_and_sum(x, y)
# Out:
#          7 function calls in 0.046 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.030    0.030    0.040    0.040 prof_mod.py:3(add_and_sum)
#         1    0.010    0.010    0.010    0.010 {method 'reduce' of 'numpy.ufunc' objects}
#         1    0.005    0.005    0.046    0.046 <string>:1(<module>)
#         1    0.000    0.000    0.046    0.046 {built-in method builtins.exec}
#         1    0.000    0.000    0.010    0.010 {method 'sum' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.010    0.010 _methods.py:46(_sum)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}

# %% [markdown]
# #### 使用%lprun

# %%
# %lprun -f add_and_sum add_and_sum(x, y)
# Out:
# Timer unit: 1e-07 s
#
# Total time: 0.0535366 s
# File: C:\Users\lpc80\PycharmProjects\learn-pydata\prof_mod.py
# Function: add_and_sum at line 3
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ...
#      3                                           def add_and_sum(x, y):
#      4         1     383734.0 383734.0     71.7      added = x + y
#      5         1     151620.0 151620.0     28.3      summed = added.sum(axis=1)
#      6         1         12.0     12.0      0.0      return summed

# %%
# %lprun -f add_and_sum -f call_function call_function()
# Out:
# Timer unit: 1e-07 s
#
# Total time: 0.005066 s
# File: C:\Users\lpc80\PycharmProjects\learn-pydata\prof_mod.py
# Function: add_and_sum at line 3
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ...
#      3                                           def add_and_sum(x, y):
#      4         1      34602.0  34602.0     68.3      added = x + y
#      5         1      16053.0  16053.0     31.7      summed = added.sum(axis=1)
#      6         1          5.0      5.0      0.0      return summed
#
# Total time: 0.0844788 s
# File: C:\Users\lpc80\PycharmProjects\learn-pydata\prof_mod.py
# Function: call_function at line 8
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ...
#      8                                           def call_function():
#      9         1     482611.0 482611.0     57.1      x = randn(1000, 1000)
#     10         1     305014.0 305014.0     36.1      y = randn(1000, 1000)
# ...

# %% [markdown]
# # 使用python的高效代码开发

# %% [markdown]
# ### 重新加载模块依赖

# %%
# 在库更新后重新加载
# import some_lib
# import importlib
# importlib.reload(some_lib)

# dreload 函数可以同时更新多层依赖

# %% [markdown]
# ### 代码设计

# %% [markdown]
# #### 保持相关对象和数据活着

# %%
# from my_functions import g
def f(x, y):
    return "a+b"
def main():
    x = 6
    y = 7.5
    result = x + y
if __name__ == '__main__':
    main()

# %%
# 访问不到上面cell中的变量
y
# Out:
# array([[-0.4160702 ,  0.5938098 ,  1.83585821, ...,  1.04411851,
#         -0.0649017 ,  0.01772076],
#        [-0.49942619, -0.12773639,  0.356966  , ...,  0.71608581,
#          0.7926809 , -0.61385305],
#        [-0.3707065 ,  0.03273419, -0.67457469, ...,  0.29837755,
#         -0.33009452, -1.35872871],
#        ...,
#        [ 0.77300824,  0.47416109, -0.60666325, ..., -0.84799276,
#         -0.61333047, -0.60304529],
#        [ 1.08414116, -1.09168371, -1.24305494, ..., -0.70259166,
#         -0.82177724, -0.34515979],
#        [ 0.34462367,  1.59520692,  0.4754645 , ..., -0.41603481,
#          0.04441906,  1.23473225]])

# %% [markdown]
# #### 扁平的结构比嵌套的好

# %% [markdown]
# #### 让每个cell有一个合理的长度

# %% [markdown]
# # 高级 IPython特性

# %% [markdown]
# ### 配置文件和配置
